# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.decomposition import FastICA
from mlxtend.frequent_patterns import association_rules

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
# Replace 'dataset_file.csv' with the actual path to your dataset file
df = pd.read_csv('diabetes.csv')
df.info() #showing information about my data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#the total num of nulls of each column 
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#getting the columns name
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
unique_education_values = df['Age'].unique()
print(unique_education_values)
# Out:
# [50 31 32 21 33 30 26 29 53 54 34 57 59 51 27 41 43 22 38 60 28 45 35 46
#  56 37 48 40 25 24 58 42 44 39 36 23 61 69 62 55 65 47 52 66 49 63 67 72
#  81 64 70 68]

# %%
unique_education_values = df['Pregnancies'].unique()
print(unique_education_values)
# Out:
# [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]

# %%
# Set the style for the plot (optional)
sns.set(style="whitegrid")
# Create a count plot for the 'Age' variable
plt.figure(figsize=(12, 8))
sns.countplot(x='Age', data=df, palette='viridis')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Set the style for the plot (optional)
sns.set(style="whitegrid")
# Create a count plot for the 'Age' variable
plt.figure(figsize=(12, 8))
sns.countplot(x='Pregnancies', data=df, palette='viridis')
plt.title('Pregnancies Distribution')
plt.xlabel('Pregnancies')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='Pregnancies', data=df, palette='viridis')
plt.title('Pregnancies Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Total Pregnancies')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='Glucose', data=df, palette='viridis')
plt.title('Glucose Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Total Glucose')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='BloodPressure', data=df, palette='viridis')
plt.title('BloodPressure Distribution by Age')
plt.xlabel('Age')
plt.ylabel('BloodPressure')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='SkinThickness', data=df, palette='viridis')
plt.title('SkinThickness Distribution by Age')
plt.xlabel('Age')
plt.ylabel('SkinThickness')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='Insulin', data=df, palette='viridis')
plt.title('Insulin Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Tota Insulin')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='BMI', data=df, palette='viridis')
plt.title('BMI Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Tota BMI')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Age', y='DiabetesPedigreeFunction', data=df, palette='viridis')
plt.title('DiabetesPedigreeFunction Distribution by Age')
plt.xlabel('Age')
plt.ylabel('DiabetesPedigreeFunction')
plt.xticks(rotation=45)
plt.show()

# %%
correlation_matrix = df.corr()
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
print(df.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Convert BMI and DiabetesPedigreeFunction columns to integers
df['BMI'] = df['BMI'].astype(int)
df['DiabetesPedigreeFunction'] = df['DiabetesPedigreeFunction'].astype(int)

# %%
df.dtypes
# Out:
# Pregnancies                 int64
# Glucose                     int64
# BloodPressure               int64
# SkinThickness               int64
# Insulin                     int64
# BMI                         int32
# DiabetesPedigreeFunction    int32
# Age                         int64
# Outcome                     int64
# cluster                     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'cluster'],
#       dtype='object')

# %%
#Principal Component Analysis (PCA):

# Select features
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
X = df[features]

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
components = pca.fit_transform(X)

# %%
# Create a new DataFrame with the principal components
df_pca = pd.DataFrame(data=components, columns=['PC1', 'PC2'])
print(df_pca)
# Out:
#            PC1        PC2
# 0   -75.717197 -35.940785
# 1   -82.360030  28.913854
# 2   -74.628227 -67.925129
# 3    11.082730  34.880106
# 4    89.747409  -2.756199
# ..         ...        ...
# 763  99.231740  25.104141
# 764 -78.646635  -7.665117
# 765  32.117209   3.359444
# 766 -80.209607 -14.204597
# 767 -81.307419  21.621617
#
# [768 rows x 2 columns]

# %%
# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df_pca['PC1'], df_pca['PC2'], alpha=0.5)
plt.title('PCA - Principal Components Scatter Plot')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.grid(True)
plt.show()

# %%
#Independent Component Analysis (ICA):

# Select features
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
X = df[features]

# %%
# Apply ICA for independent component analysis
ica = FastICA(n_components=3)
components = ica.fit_transform(X)

# %%
# Create a new DataFrame with the independent components
df_ica = pd.DataFrame(data=components, columns=['IC1', 'IC2', 'IC3'])
print(df_ica)
# Out:
#           IC1       IC2       IC3
# 0   -0.011807  0.042757  0.023851
# 1   -0.003774 -0.033477  0.028122
# 2    0.033938  0.083016  0.014315
# 3    0.001710 -0.041305 -0.001894
# 4    0.040719  0.004404 -0.035077
# ..        ...       ...       ...
# 763 -0.038223 -0.032856 -0.023671
# 764 -0.004005  0.009749  0.025021
# 765 -0.004281 -0.004566 -0.009239
# 766  0.025131  0.019050  0.020403
# 767 -0.009161 -0.025147  0.028278
#
# [768 rows x 3 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D


# 3D Scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df_ica['IC1'], df_ica['IC2'], df_ica['IC3'], alpha=0.5)
ax.set_title('ICA - Independent Components 3D Scatter Plot')
ax.set_xlabel('Independent Component 1 (IC1)')
ax.set_ylabel('Independent Component 2 (IC2)')
ax.set_zlabel('Independent Component 3 (IC3)')

plt.show()

# %%
#DBSCAN:

#library for it
from sklearn.cluster import DBSCAN

features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
X = df[features]

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
df['cluster'] = dbscan.fit_predict(X)
print(df['cluster'])
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 763   -1
# 764   -1
# 765   -1
# 766   -1
# 767   -1
# Name: cluster, Length: 768, dtype: int64

# %%
# Scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Pregnancies', y='Glucose', hue='cluster', data=df, palette='viridis', legend='full', alpha=0.7)
plt.title('DBSCAN Clustering')
plt.xlabel('Pregnancies')
plt.ylabel('Glucose')
plt.show()

# %%
#t-Distributed Stochastic Neighbor Embedding (t-SNE):

#library for it
from sklearn.manifold import TSNE

# Assuming df is your DataFrame with features
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
X = df[features]


# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2)
components = tsne.fit_transform(X)
df_tsne = pd.DataFrame(data=components, columns=['TSNE1', 'TSNE2'])
print(df_tsne)
# Out:
#          TSNE1      TSNE2
# 0   -30.074053 -18.029146
# 1   -14.935495  -7.308676
# 2   -40.298130 -18.130579
# 3    13.334614  15.760450
# 4    31.556183   4.666368
# ..         ...        ...
# 763  37.132698   1.599110
# 764 -21.832092 -14.169471
# 765  19.273775   8.148802
# 766 -34.350269  -5.878681
# 767 -16.037203  -8.686195
#
# [768 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Assuming df is your DataFrame with features
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
X = df[features]

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=42)
components = tsne.fit_transform(X)
df_tsne = pd.DataFrame(data=components, columns=['TSNE1', 'TSNE2'])

# Scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(df_tsne['TSNE1'], df_tsne['TSNE2'], alpha=0.7)
plt.title('t-SNE Visualization')
plt.xlabel('t-SNE Component 1 (TSNE1)')
plt.ylabel('t-SNE Component 2 (TSNE2)')
plt.show()
